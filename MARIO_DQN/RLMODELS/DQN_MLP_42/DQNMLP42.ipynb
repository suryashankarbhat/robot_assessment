# %%
# !pip install gym_super_mario_bros==7.3.0 nes_py
# Out:
# ^C

# %%
# Install pytorch
# !pip install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio===0.10.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# Out:
# ^C

# %%
# !pip install stable-baselines3[extra]
# Out:
# Collecting gym_super_mario_bros==7.3.0
#   Downloading gym_super_mario_bros-7.3.0-py2.py3-none-any.whl (198 kB)
# Collecting nes_py
#   Downloading nes_py-8.1.8.tar.gz (76 kB)
# Collecting gym>=0.17.2
#   Downloading gym-0.23.1.tar.gz (626 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: numpy>=1.18.5 in c:\programdata\anaconda3\lib\site-packages (from nes_py) (1.20.1)
# Collecting pyglet<=1.5.11,>=1.4.0
#   Downloading pyglet-1.5.11-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: tqdm>=4.48.2 in c:\programdata\anaconda3\lib\site-packages (from nes_py) (4.59.0)
# Collecting gym-notices>=0.0.4
#   Downloading gym_notices-0.0.6-py3-none-any.whl (2.7 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from gym>=0.17.2->nes_py) (1.6.0)
# Collecting importlib-metadata>=4.10.0
#   Downloading importlib_metadata-4.11.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.10.0->gym>=0.17.2->nes_py) (3.4.1)
# Building wheels for collected packages: nes-py, gym
#   Building wheel for nes-py (setup.py): started
#   Building wheel for nes-py (setup.py): finished with status 'done'
#   Created wheel for nes-py: filename=nes_py-8.1.8-cp38-cp38-win_amd64.whl size=47360 sha256=f71ae429e2466d674ee0f1375580f14392353362878007d6c7ab627a8d5c1f95
#   Stored in directory: c:\users\computing\appdata\local\pip\cache\wheels\8d\6e\f0\113c979eba40def28ee9b3c81a4adec00386106d81fb3bc2c2
#   Building wheel for gym (PEP 517): started
#   Building wheel for gym (PEP 517): finished with status 'done'
#   Created wheel for gym: filename=gym-0.23.1-py3-none-any.whl size=701358 sha256=f8d451dd55695bf0e8ab33b8d59855a89a872c956a2322b67ff891a5b3c1f2c4
#   Stored in directory: c:\users\computing\appdata\local\pip\cache\wheels\78\28\77\b0c74e80a2a4faae0161d5c53bc4f8e436e77aedc79136ee13
# Successfully built nes-py gym
# Installing collected packages: importlib-metadata, gym-notices, pyglet, gym, nes-py, gym-super-mario-bros
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.10.0
#     Uninstalling importlib-metadata-3.10.0:
#       Successfully uninstalled importlib-metadata-3.10.0
# Successfully installed gym-0.23.1 gym-notices-0.0.6 gym-super-mario-bros-7.3.0 importlib-metadata-4.11.3 nes-py-8.1.8 pyglet-1.5.11
# ^C

# %%
# Import the game
import gym_super_mario_bros
# Import the Joypad wrapper
from nes_py.wrappers import JoypadSpace
# Import the SIMPLIFIED controls
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
from stable_baselines3.common.callbacks import BaseCallback

# %%
# Setup game
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\ProgramData\Anaconda3\lib\site-packages\gym\envs\registration.py:505: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3` with the environment ID `SuperMarioBros-v3`.
#   logger.warn(

# %%
# Setup game
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
# Setup model saving callback
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %%
# Import Frame Stacker Wrapper and GrayScaling Wrapper
from gym.wrappers import GrayScaleObservation
# Import Vectorization Wrappers
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
# Import Matplotlib to show the impact of frame stacking
from matplotlib import pyplot as plt

# %%
# Import os for file path management
import os 
# Import PPO for algos
from stable_baselines3 import DQN
# Import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback

# %%
#dqn model with seed 42
model = DQN('MlpPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.000001,seed=42,buffer_size=100)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=2000000, callback=callback)
# Out:
# Logging to ./logs/DQN_1
# C:\ProgramData\Anaconda3\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+04 |
# |    ep_rew_mean      | 575      |
# |    exploration_rate | 0.617    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 363      |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 80558    |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.112    |
# |    n_updates        | 7639     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.55e+04 |
# |    ep_rew_mean      | 774      |
# |    exploration_rate | 0.409    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 272      |
# |    time_elapsed     | 456      |
# |    total_timesteps  | 124356   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.0924   |
# |    n_updates        | 18588    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.18e+04 |
# |    ep_rew_mean      | 1.21e+03 |
# |    exploration_rate | 0.329    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 256      |
# |    time_elapsed     | 550      |
# |    total_timesteps  | 141202   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.682    |
# |    n_updates        | 22800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.4e+03  |
# |    ep_rew_mean      | 1.33e+03 |
# |    exploration_rate | 0.286    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 249      |
# |    time_elapsed     | 601      |
# |    total_timesteps  | 150362   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.701    |
# |    n_updates        | 25090    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.08e+03 |
# |    ep_rew_mean      | 1.51e+03 |
# |    exploration_rate | 0.232    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 243      |
# |    time_elapsed     | 663      |
# |    total_timesteps  | 161698   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.6      |
# |    n_updates        | 27924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.99e+03 |
# |    ep_rew_mean      | 1.6e+03  |
# |    exploration_rate | 0.203    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 241      |
# |    time_elapsed     | 695      |
# |    total_timesteps  | 167766   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.11     |
# |    n_updates        | 29441    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.13e+03 |
# |    ep_rew_mean      | 1.61e+03 |
# |    exploration_rate | 0.185    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 239      |
# |    time_elapsed     | 716      |
# |    total_timesteps  | 171543   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.853    |
# |    n_updates        | 30385    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.53e+03 |
# |    ep_rew_mean      | 1.66e+03 |
# |    exploration_rate | 0.159    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 237      |
# |    time_elapsed     | 745      |
# |    total_timesteps  | 176957   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.42     |
# |    n_updates        | 31739    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.04e+03 |
# |    ep_rew_mean      | 1.64e+03 |
# |    exploration_rate | 0.139    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 235      |
# |    time_elapsed     | 770      |
# |    total_timesteps  | 181332   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.857    |
# |    n_updates        | 32832    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.67e+03 |
# |    ep_rew_mean      | 1.71e+03 |
# |    exploration_rate | 0.112    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 233      |
# |    time_elapsed     | 801      |
# |    total_timesteps  | 186995   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.459    |
# |    n_updates        | 34248    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.34e+03 |
# |    ep_rew_mean      | 1.72e+03 |
# |    exploration_rate | 0.0932   |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 232      |
# |    time_elapsed     | 822      |
# |    total_timesteps  | 190903   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.255    |
# |    n_updates        | 35225    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | 1.7e+03  |
# |    exploration_rate | 0.0786   |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 231      |
# |    time_elapsed     | 839      |
# |    total_timesteps  | 193971   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.484    |
# |    n_updates        | 35992    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 1.69e+03 |
# |    exploration_rate | 0.0612   |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 229      |
# |    time_elapsed     | 861      |
# |    total_timesteps  | 197635   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.435    |
# |    n_updates        | 36908    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | 1.71e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 227      |
# |    time_elapsed     | 889      |
# |    total_timesteps  | 202422   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.714    |
# |    n_updates        | 38105    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.41e+03 |
# |    ep_rew_mean      | 1.67e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 226      |
# |    time_elapsed     | 903      |
# |    total_timesteps  | 204765   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.862    |
# |    n_updates        | 38691    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 1.67e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 225      |
# |    time_elapsed     | 926      |
# |    total_timesteps  | 208674   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.944    |
# |    n_updates        | 39668    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 1.66e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 223      |
# |    time_elapsed     | 947      |
# |    total_timesteps  | 212270   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.506    |
# |    n_updates        | 40567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.01e+03 |
# |    ep_rew_mean      | 1.68e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 222      |
# |    time_elapsed     | 974      |
# |    total_timesteps  | 216829   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.239    |
# |    n_updates        | 41707    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.88e+03 |
# |    ep_rew_mean      | 1.64e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 221      |
# |    time_elapsed     | 986      |
# |    total_timesteps  | 218969   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.634    |
# |    n_updates        | 42242    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.77e+03 |
# |    ep_rew_mean      | 1.62e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 220      |
# |    time_elapsed     | 1003     |
# |    total_timesteps  | 221731   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.1      |
# |    n_updates        | 42932    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.67e+03 |
# |    ep_rew_mean      | 1.6e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 220      |
# |    time_elapsed     | 1020     |
# |    total_timesteps  | 224608   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.11     |
# |    n_updates        | 43651    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.6e+03  |
# |    ep_rew_mean      | 1.6e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 219      |
# |    time_elapsed     | 1044     |
# |    total_timesteps  | 228764   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.21     |
# |    n_updates        | 44690    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.52e+03 |
# |    ep_rew_mean      | 1.59e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 218      |
# |    time_elapsed     | 1061     |
# |    total_timesteps  | 231603   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.607    |
# |    n_updates        | 45400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.45e+03 |
# |    ep_rew_mean      | 1.59e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 217      |
# |    time_elapsed     | 1082     |
# |    total_timesteps  | 235071   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.951    |
# |    n_updates        | 46267    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.38e+03 |
# |    ep_rew_mean      | 1.58e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 216      |
# |    time_elapsed     | 1101     |
# |    total_timesteps  | 238287   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.602    |
# |    n_updates        | 47071    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.62e+03 |
# |    ep_rew_mean      | 1.63e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 215      |
# |    time_elapsed     | 1125     |
# |    total_timesteps  | 242145   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.617    |
# |    n_updates        | 48036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.21e+03 |
# |    ep_rew_mean      | 1.64e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 214      |
# |    time_elapsed     | 1142     |
# |    total_timesteps  | 244952   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.413    |
# |    n_updates        | 48737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.08e+03 |
# |    ep_rew_mean      | 1.63e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 213      |
# |    time_elapsed     | 1166     |
# |    total_timesteps  | 249126   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.819    |
# |    n_updates        | 49781    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02e+03 |
# |    ep_rew_mean      | 1.62e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 212      |
# |    time_elapsed     | 1186     |
# |    total_timesteps  | 252444   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.745    |
# |    n_updates        | 50610    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 932      |
# |    ep_rew_mean      | 1.57e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 212      |
# |    time_elapsed     | 1201     |
# |    total_timesteps  | 254886   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.926    |
# |    n_updates        | 51221    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 918      |
# |    ep_rew_mean      | 1.56e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 211      |
# |    time_elapsed     | 1228     |
# |    total_timesteps  | 259614   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.598    |
# |    n_updates        | 52403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 918      |
# |    ep_rew_mean      | 1.55e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 210      |
# |    time_elapsed     | 1251     |
# |    total_timesteps  | 263329   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.394    |
# |    n_updates        | 53332    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 907      |
# |    ep_rew_mean      | 1.54e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 209      |
# |    time_elapsed     | 1276     |
# |    total_timesteps  | 267697   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.61     |
# |    n_updates        | 54424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 944      |
# |    ep_rew_mean      | 1.55e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 208      |
# |    time_elapsed     | 1324     |
# |    total_timesteps  | 275765   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.72     |
# |    n_updates        | 56441    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 932      |
# |    ep_rew_mean      | 1.52e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 207      |
# |    time_elapsed     | 1350     |
# |    total_timesteps  | 280226   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.988    |
# |    n_updates        | 57556    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 912      |
# |    ep_rew_mean      | 1.48e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 207      |
# |    time_elapsed     | 1361     |
# |    total_timesteps  | 282070   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.65     |
# |    n_updates        | 58017    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 912      |
# |    ep_rew_mean      | 1.47e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 206      |
# |    time_elapsed     | 1379     |
# |    total_timesteps  | 285190   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.609    |
# |    n_updates        | 58797    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 913      |
# |    ep_rew_mean      | 1.47e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 206      |
# |    time_elapsed     | 1401     |
# |    total_timesteps  | 288977   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.459    |
# |    n_updates        | 59744    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 929      |
# |    ep_rew_mean      | 1.49e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 205      |
# |    time_elapsed     | 1438     |
# |    total_timesteps  | 295358   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.257    |
# |    n_updates        | 61339    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 947      |
# |    ep_rew_mean      | 1.51e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 204      |
# |    time_elapsed     | 1462     |
# |    total_timesteps  | 299426   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.314    |
# |    n_updates        | 62356    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 934      |
# |    ep_rew_mean      | 1.49e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 204      |
# |    time_elapsed     | 1478     |
# |    total_timesteps  | 302123   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.737    |
# |    n_updates        | 63030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 942      |
# |    ep_rew_mean      | 1.5e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 203      |
# |    time_elapsed     | 1502     |
# |    total_timesteps  | 306443   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.412    |
# |    n_updates        | 64110    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 933      |
# |    ep_rew_mean      | 1.49e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 203      |
# |    time_elapsed     | 1523     |
# |    total_timesteps  | 310098   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.59     |
# |    n_updates        | 65024    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 944      |
# |    ep_rew_mean      | 1.5e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 203      |
# |    time_elapsed     | 1541     |
# |    total_timesteps  | 313408   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.08     |
# |    n_updates        | 65851    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 970      |
# |    ep_rew_mean      | 1.51e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 202      |
# |    time_elapsed     | 1570     |
# |    total_timesteps  | 318743   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.714    |
# |    n_updates        | 67185    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 994      |
# |    ep_rew_mean      | 1.54e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 202      |
# |    time_elapsed     | 1600     |
# |    total_timesteps  | 324050   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.14     |
# |    n_updates        | 68512    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 988      |
# |    ep_rew_mean      | 1.55e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 202      |
# |    time_elapsed     | 1620     |
# |    total_timesteps  | 327614   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.67     |
# |    n_updates        | 69403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 989      |
# |    ep_rew_mean      | 1.55e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 201      |
# |    time_elapsed     | 1637     |
# |    total_timesteps  | 330465   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.767    |
# |    n_updates        | 70116    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 996      |
# |    ep_rew_mean      | 1.55e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 201      |
# |    time_elapsed     | 1661     |
# |    total_timesteps  | 334690   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.913    |
# |    n_updates        | 71172    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 994      |
# |    ep_rew_mean      | 1.55e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 201      |
# |    time_elapsed     | 1679     |
# |    total_timesteps  | 337705   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.4      |
# |    n_updates        | 71926    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 1.57e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 200      |
# |    time_elapsed     | 1707     |
# |    total_timesteps  | 342471   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.825    |
# |    n_updates        | 73117    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 1.57e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 200      |
# |    time_elapsed     | 1723     |
# |    total_timesteps  | 345210   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.832    |
# |    n_updates        | 73802    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 995      |
# |    ep_rew_mean      | 1.56e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 199      |
# |    time_elapsed     | 1743     |
# |    total_timesteps  | 348669   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.76     |
# |    n_updates        | 74667    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 1.57e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 199      |
# |    time_elapsed     | 1767     |
# |    total_timesteps  | 352679   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.739    |
# |    n_updates        | 75669    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 1.58e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 199      |
# |    time_elapsed     | 1782     |
# |    total_timesteps  | 355251   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.674    |
# |    n_updates        | 76312    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 985      |
# |    ep_rew_mean      | 1.56e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 199      |
# |    time_elapsed     | 1799     |
# |    total_timesteps  | 358105   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.919    |
# |    n_updates        | 77026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 987      |
# |    ep_rew_mean      | 1.56e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 198      |
# |    time_elapsed     | 1822     |
# |    total_timesteps  | 362052   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.738    |
# |    n_updates        | 78012    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 977      |
# |    ep_rew_mean      | 1.55e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 198      |
# |    time_elapsed     | 1840     |
# |    total_timesteps  | 365359   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.743    |
# |    n_updates        | 78839    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 936      |
# |    ep_rew_mean      | 1.54e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 198      |
# |    time_elapsed     | 1862     |
# |    total_timesteps  | 369323   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.82     |
# |    n_updates        | 79830    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 921      |
# |    ep_rew_mean      | 1.54e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 198      |
# |    time_elapsed     | 1880     |
# |    total_timesteps  | 372304   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.583    |
# |    n_updates        | 80575    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 949      |
# |    ep_rew_mean      | 1.57e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 197      |
# |    time_elapsed     | 1906     |
# |    total_timesteps  | 376973   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.509    |
# |    n_updates        | 81743    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 964      |
# |    ep_rew_mean      | 1.58e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 197      |
# |    time_elapsed     | 1932     |
# |    total_timesteps  | 381588   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.687    |
# |    n_updates        | 82896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 967      |
# |    ep_rew_mean      | 1.59e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 197      |
# |    time_elapsed     | 1955     |
# |    total_timesteps  | 385663   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.701    |
# |    n_updates        | 83915    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 939      |
# |    ep_rew_mean      | 1.57e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 197      |
# |    time_elapsed     | 1975     |
# |    total_timesteps  | 389282   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.714    |
# |    n_updates        | 84820    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 919      |
# |    ep_rew_mean      | 1.55e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 196      |
# |    time_elapsed     | 1987     |
# |    total_timesteps  | 391364   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.572    |
# |    n_updates        | 85340    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 933      |
# |    ep_rew_mean      | 1.57e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 196      |
# |    time_elapsed     | 2009     |
# |    total_timesteps  | 395408   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.15     |
# |    n_updates        | 86351    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 939      |
# |    ep_rew_mean      | 1.56e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 196      |
# |    time_elapsed     | 2037     |
# |    total_timesteps  | 400353   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.752    |
# |    n_updates        | 87588    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 937      |
# |    ep_rew_mean      | 1.55e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 196      |
# |    time_elapsed     | 2056     |
# |    total_timesteps  | 403775   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.01     |
# |    n_updates        | 88443    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 934      |
# |    ep_rew_mean      | 1.55e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 196      |
# |    time_elapsed     | 2073     |
# |    total_timesteps  | 406839   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.36     |
# |    n_updates        | 89209    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 914      |
# |    ep_rew_mean      | 1.54e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 195      |
# |    time_elapsed     | 2093     |
# |    total_timesteps  | 410149   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.909    |
# |    n_updates        | 90037    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 901      |
# |    ep_rew_mean      | 1.52e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 195      |
# |    time_elapsed     | 2116     |
# |    total_timesteps  | 414149   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.34     |
# |    n_updates        | 91037    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 907      |
# |    ep_rew_mean      | 1.52e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 195      |
# |    time_elapsed     | 2140     |
# |    total_timesteps  | 418317   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.02     |
# |    n_updates        | 92079    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 917      |
# |    ep_rew_mean      | 1.54e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 195      |
# |    time_elapsed     | 2163     |
# |    total_timesteps  | 422150   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.22     |
# |    n_updates        | 93037    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 914      |
# |    ep_rew_mean      | 1.53e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 194      |
# |    time_elapsed     | 2186     |
# |    total_timesteps  | 426122   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.49     |
# |    n_updates        | 94030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 924      |
# |    ep_rew_mean      | 1.54e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 194      |
# |    time_elapsed     | 2209     |
# |    total_timesteps  | 430123   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.819    |
# |    n_updates        | 95030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 910      |
# |    ep_rew_mean      | 1.51e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 194      |
# |    time_elapsed     | 2228     |
# |    total_timesteps  | 433508   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.12     |
# |    n_updates        | 95876    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 925      |
# |    ep_rew_mean      | 1.53e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 194      |
# |    time_elapsed     | 2251     |
# |    total_timesteps  | 437693   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.28     |
# |    n_updates        | 96923    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 923      |
# |    ep_rew_mean      | 1.53e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 194      |
# |    time_elapsed     | 2270     |
# |    total_timesteps  | 440993   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.05     |
# |    n_updates        | 97748    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 916      |
# |    ep_rew_mean      | 1.51e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 194      |
# |    time_elapsed     | 2289     |
# |    total_timesteps  | 444296   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.89     |
# |    n_updates        | 98573    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 914      |
# |    ep_rew_mean      | 1.5e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 193      |
# |    time_elapsed     | 2302     |
# |    total_timesteps  | 446620   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.702    |
# |    n_updates        | 99154    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 925      |
# |    ep_rew_mean      | 1.52e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 193      |
# |    time_elapsed     | 2325     |
# |    total_timesteps  | 450639   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.75     |
# |    n_updates        | 100159   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 924      |
# |    ep_rew_mean      | 1.52e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 193      |
# |    time_elapsed     | 2346     |
# |    total_timesteps  | 454453   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.5      |
# |    n_updates        | 101113   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 927      |
# |    ep_rew_mean      | 1.51e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 193      |
# |    time_elapsed     | 2366     |
# |    total_timesteps  | 458042   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.579    |
# |    n_updates        | 102010   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 919      |
# |    ep_rew_mean      | 1.49e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 193      |
# |    time_elapsed     | 2385     |
# |    total_timesteps  | 461232   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.94     |
# |    n_updates        | 102807   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 918      |
# |    ep_rew_mean      | 1.49e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 193      |
# |    time_elapsed     | 2401     |
# |    total_timesteps  | 464138   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.64     |
# |    n_updates        | 103534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 931      |
# |    ep_rew_mean      | 1.5e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 193      |
# |    time_elapsed     | 2435     |
# |    total_timesteps  | 470025   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.33     |
# |    n_updates        | 105006   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 924      |
# |    ep_rew_mean      | 1.5e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 192      |
# |    time_elapsed     | 2457     |
# |    total_timesteps  | 473979   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.68     |
# |    n_updates        | 105994   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 917      |
# |    ep_rew_mean      | 1.49e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 192      |
# |    time_elapsed     | 2476     |
# |    total_timesteps  | 477400   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.1      |
# |    n_updates        | 106849   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 926      |
# |    ep_rew_mean      | 1.5e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 192      |
# |    time_elapsed     | 2501     |
# |    total_timesteps  | 481907   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.657    |
# |    n_updates        | 107976   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 951      |
# |    ep_rew_mean      | 1.52e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 192      |
# |    time_elapsed     | 2527     |
# |    total_timesteps  | 486477   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 2.38     |
# |    n_updates        | 109119   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 956      |
# |    ep_rew_mean      | 1.52e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 192      |
# |    time_elapsed     | 2553     |
# |    total_timesteps  | 491025   |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.21     |
# |    n_updates        | 110256   |
# ----------------------------------
# ...
# |    time_elapsed     | 10536    |
# |    total_timesteps  | 1865720  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.192    |
# |    n_updates        | 453929   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 971      |
# |    ep_rew_mean      | 1.64e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1744     |
# |    fps              | 177      |
# |    time_elapsed     | 10563    |
# |    total_timesteps  | 1870163  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 2.37     |
# |    n_updates        | 455040   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 986      |
# |    ep_rew_mean      | 1.66e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1748     |
# |    fps              | 177      |
# |    time_elapsed     | 10592    |
# |    total_timesteps  | 1875222  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.758    |
# |    n_updates        | 456305   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 996      |
# |    ep_rew_mean      | 1.66e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1752     |
# |    fps              | 177      |
# |    time_elapsed     | 10618    |
# |    total_timesteps  | 1879662  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 2.16     |
# |    n_updates        | 457415   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 979      |
# |    ep_rew_mean      | 1.64e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1756     |
# |    fps              | 176      |
# |    time_elapsed     | 10633    |
# |    total_timesteps  | 1882058  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.8      |
# |    n_updates        | 458014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 978      |
# |    ep_rew_mean      | 1.64e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1760     |
# |    fps              | 176      |
# |    time_elapsed     | 10649    |
# |    total_timesteps  | 1884863  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 2.32     |
# |    n_updates        | 458715   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 986      |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1764     |
# |    fps              | 176      |
# |    time_elapsed     | 10675    |
# |    total_timesteps  | 1889362  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 3.24     |
# |    n_updates        | 459840   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 969      |
# |    ep_rew_mean      | 1.63e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1768     |
# |    fps              | 176      |
# |    time_elapsed     | 10698    |
# |    total_timesteps  | 1893268  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.78     |
# |    n_updates        | 460816   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 954      |
# |    ep_rew_mean      | 1.61e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1772     |
# |    fps              | 176      |
# |    time_elapsed     | 10713    |
# |    total_timesteps  | 1895840  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.918    |
# |    n_updates        | 461459   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 953      |
# |    ep_rew_mean      | 1.61e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1776     |
# |    fps              | 176      |
# |    time_elapsed     | 10737    |
# |    total_timesteps  | 1899916  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.125    |
# |    n_updates        | 462478   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 955      |
# |    ep_rew_mean      | 1.61e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1780     |
# |    fps              | 176      |
# |    time_elapsed     | 10760    |
# |    total_timesteps  | 1903801  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.05     |
# |    n_updates        | 463450   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 945      |
# |    ep_rew_mean      | 1.58e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1784     |
# |    fps              | 176      |
# |    time_elapsed     | 10777    |
# |    total_timesteps  | 1906831  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.94     |
# |    n_updates        | 464207   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 943      |
# |    ep_rew_mean      | 1.59e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1788     |
# |    fps              | 176      |
# |    time_elapsed     | 10800    |
# |    total_timesteps  | 1910654  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 2.63     |
# |    n_updates        | 465163   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 941      |
# |    ep_rew_mean      | 1.59e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1792     |
# |    fps              | 176      |
# |    time_elapsed     | 10822    |
# |    total_timesteps  | 1914407  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.57     |
# |    n_updates        | 466101   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 925      |
# |    ep_rew_mean      | 1.57e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1796     |
# |    fps              | 176      |
# |    time_elapsed     | 10842    |
# |    total_timesteps  | 1917835  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.27     |
# |    n_updates        | 466958   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 978      |
# |    ep_rew_mean      | 1.64e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1800     |
# |    fps              | 176      |
# |    time_elapsed     | 10885    |
# |    total_timesteps  | 1925378  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.743    |
# |    n_updates        | 468844   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 983      |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1804     |
# |    fps              | 176      |
# |    time_elapsed     | 10907    |
# |    total_timesteps  | 1929128  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1        |
# |    n_updates        | 469781   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 1.66e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1808     |
# |    fps              | 176      |
# |    time_elapsed     | 10942    |
# |    total_timesteps  | 1935121  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.12     |
# |    n_updates        | 471280   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02e+03 |
# |    ep_rew_mean      | 1.67e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1812     |
# |    fps              | 176      |
# |    time_elapsed     | 10973    |
# |    total_timesteps  | 1940301  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.453    |
# |    n_updates        | 472575   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04e+03 |
# |    ep_rew_mean      | 1.68e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1816     |
# |    fps              | 176      |
# |    time_elapsed     | 11005    |
# |    total_timesteps  | 1945725  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.68     |
# |    n_updates        | 473931   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05e+03 |
# |    ep_rew_mean      | 1.69e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1820     |
# |    fps              | 176      |
# |    time_elapsed     | 11037    |
# |    total_timesteps  | 1951163  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 0.735    |
# |    n_updates        | 475290   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.09e+03 |
# |    ep_rew_mean      | 1.71e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1824     |
# |    fps              | 176      |
# |    time_elapsed     | 11078    |
# |    total_timesteps  | 1958191  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.39     |
# |    n_updates        | 477047   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.11e+03 |
# |    ep_rew_mean      | 1.7e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1828     |
# |    fps              | 176      |
# |    time_elapsed     | 11109    |
# |    total_timesteps  | 1963512  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1        |
# |    n_updates        | 478377   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.11e+03 |
# |    ep_rew_mean      | 1.71e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1832     |
# |    fps              | 176      |
# |    time_elapsed     | 11134    |
# |    total_timesteps  | 1967767  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.76     |
# |    n_updates        | 479441   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.12e+03 |
# |    ep_rew_mean      | 1.72e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1836     |
# |    fps              | 176      |
# |    time_elapsed     | 11161    |
# |    total_timesteps  | 1972320  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.87     |
# |    n_updates        | 480579   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.13e+03 |
# |    ep_rew_mean      | 1.7e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1840     |
# |    fps              | 176      |
# |    time_elapsed     | 11198    |
# |    total_timesteps  | 1978597  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.51     |
# |    n_updates        | 482149   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.13e+03 |
# |    ep_rew_mean      | 1.7e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1844     |
# |    fps              | 176      |
# |    time_elapsed     | 11226    |
# |    total_timesteps  | 1983445  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 2.22     |
# |    n_updates        | 483361   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.11e+03 |
# |    ep_rew_mean      | 1.68e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1848     |
# |    fps              | 176      |
# |    time_elapsed     | 11244    |
# |    total_timesteps  | 1986474  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 2.21     |
# |    n_updates        | 484118   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.11e+03 |
# |    ep_rew_mean      | 1.67e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1852     |
# |    fps              | 176      |
# |    time_elapsed     | 11267    |
# |    total_timesteps  | 1990233  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 1.38     |
# |    n_updates        | 485058   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.12e+03 |
# |    ep_rew_mean      | 1.69e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1856     |
# |    fps              | 176      |
# |    time_elapsed     | 11292    |
# |    total_timesteps  | 1994519  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 2.84     |
# |    n_updates        | 486129   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.14e+03 |
# |    ep_rew_mean      | 1.71e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1860     |
# |    fps              | 176      |
# |    time_elapsed     | 11317    |
# |    total_timesteps  | 1998865  |
# | train/              |          |
# |    learning_rate    | 1e-06    |
# |    loss             | 3.84     |
# |    n_updates        | 487216   |
# ----------------------------------

# %%
model.save('thisisatestdqnseed42model')
